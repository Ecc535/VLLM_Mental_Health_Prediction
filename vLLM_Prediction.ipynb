# %% [markdown]
# <a href="https://colab.research.google.com/github/Ecc535/VLLM_Mental_Health_Prediction/blob/main/vLLM_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://huggingface.co/nvidia/Llama-3.1-Nemotron-Nano-4B-v1.1
# Out:
# Cloning into 'Llama-3.1-Nemotron-Nano-4B-v1.1'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 85 (delta 7), reused 0 (delta 0), pack-reused 70 (from 1)
# Receiving objects: 100% (85/85), 84.89 KiB | 1.33 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# Filtering content: 100% (3/3), 4.42 GiB | 73.57 MiB/s, done.
# Encountered 2 file(s) that may not have been copied correctly on Windows:
# 	model-00002-of-00002.safetensors
# 	model-00001-of-00002.safetensors
#
# See: `git lfs help smudge` for more details.

# %%
# !pip install -U vllm
# !pip uninstall -y protobuf
# !pip install protobuf==4.25.3
# Out:
# Collecting vllm
#   Downloading vllm-0.16.0-cp38-abi3-manylinux_2_31_x86_64.whl.metadata (9.4 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from vllm) (2025.11.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from vllm) (6.2.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from vllm) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from vllm) (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from vllm) (2.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from vllm) (4.67.3)
# Collecting blake3 (from vllm)
#   Downloading blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from vllm) (9.0.0)
# Collecting transformers<5,>=4.56.0 (from vllm)
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.21.1 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.22.2)
# Requirement already satisfied: protobuf!=6.30.*,!=6.31.*,!=6.32.*,!=6.33.0.*,!=6.33.1.*,!=6.33.2.*,!=6.33.3.*,!=6.33.4.*,>=5.29.6 in /usr/local/lib/python3.12/dist-packages (from vllm) (5.29.6)
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.133.0)
# Requirement already satisfied: aiohttp>=3.13.3 in /usr/local/lib/python3.12/dist-packages (from vllm) (3.13.3)
# Requirement already satisfied: openai>=1.99.1 in /usr/local/lib/python3.12/dist-packages (from vllm) (2.23.0)
# Requirement already satisfied: pydantic>=2.12.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (2.12.3)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.24.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from vllm) (11.3.0)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm)
#   Downloading prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.12.0)
# Collecting lm-format-enforcer==0.11.3 (from vllm)
#   Downloading lm_format_enforcer-0.11.3-py3-none-any.whl.metadata (17 kB)
# Collecting llguidance<1.4.0,>=1.3.0 (from vllm)
#   Downloading llguidance-1.3.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting outlines_core==0.2.11 (from vllm)
#   Downloading outlines_core-0.2.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting diskcache==5.6.3 (from vllm)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting lark==1.2.2 (from vllm)
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting xgrammar==0.1.29 (from vllm)
#   Downloading xgrammar-0.1.29-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from vllm) (4.15.0)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.12/dist-packages (from vllm) (3.24.3)
# Collecting partial-json-parser (from vllm)
#   Downloading partial_json_parser-0.2.1.1.post7-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (26.2.1)
# Collecting msgspec (from vllm)
#   Downloading msgspec-0.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting gguf>=0.17.0 (from vllm)
#   Downloading gguf-0.17.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting mistral_common>=1.9.0 (from mistral_common[image]>=1.9.0->vllm)
#   Downloading mistral_common-1.9.1-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: opencv-python-headless>=4.13.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (4.13.0.92)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from vllm) (6.0.3)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.17.0)
# Collecting setuptools<81.0.0,>=77.0.3 (from vllm)
#   Downloading setuptools-80.10.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from vllm) (0.8.2)
# Collecting compressed-tensors==0.13.0 (from vllm)
#   Downloading compressed_tensors-0.13.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting depyf==0.20.0 (from vllm)
#   Downloading depyf-0.20.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from vllm) (3.1.2)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.12/dist-packages (from vllm) (1.1.1)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.12/dist-packages (from vllm) (4.0.0)
# Collecting ninja (from vllm)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting pybase64 (from vllm)
#   Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Collecting cbor2 (from vllm)
#   Downloading cbor2-5.8.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting ijson (from vllm)
#   Downloading ijson-3.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Collecting setproctitle (from vllm)
#   Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (10 kB)
# Collecting openai-harmony>=0.0.3 (from vllm)
#   Downloading openai_harmony-0.0.8-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Collecting anthropic>=0.71.0 (from vllm)
#   Downloading anthropic-0.84.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting model-hosting-container-standards<1.0.0,>=0.1.13 (from vllm)
#   Downloading model_hosting_container_standards-0.1.13-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: mcp in /usr/local/lib/python3.12/dist-packages (from vllm) (1.26.0)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.12/dist-packages (from vllm) (1.78.1)
# Collecting grpcio-reflection (from vllm)
#   Downloading grpcio_reflection-1.78.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting numba==0.61.2 (from vllm)
#   Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting ray>=2.48.0 (from ray[cgraph]>=2.48.0->vllm)
#   Downloading ray-2.54.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting torch==2.9.1 (from vllm)
#   Downloading torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchaudio==2.9.1 (from vllm)
#   Downloading torchaudio-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Collecting torchvision==0.24.1 (from vllm)
#   Downloading torchvision-0.24.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Collecting flashinfer-python==0.6.3 (from vllm)
#   Downloading flashinfer_python-0.6.3-py3-none-any.whl.metadata (10 kB)
# Collecting loguru (from compressed-tensors==0.13.0->vllm)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting astor (from depyf==0.20.0->vllm)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from depyf==0.20.0->vllm) (0.3.8)
# Collecting apache-tvm-ffi!=0.1.8,!=0.1.8.post0,<0.2,>=0.1.6 (from flashinfer-python==0.6.3->vllm)
#   Downloading apache_tvm_ffi-0.1.8.post2-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.6.3->vllm) (8.3.1)
# Collecting nvidia-cudnn-frontend>=1.13.0 (from flashinfer-python==0.6.3->vllm)
#   Downloading nvidia_cudnn_frontend-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Collecting nvidia-cutlass-dsl>=4.3.4 (from flashinfer-python==0.6.3->vllm)
#   Downloading nvidia_cutlass_dsl-4.4.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.6.3->vllm) (13.590.48)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.6.3->vllm) (26.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.6.3->vllm) (0.9.0)
# Collecting interegular>=0.3.2 (from lm-format-enforcer==0.11.3->vllm)
#   Downloading interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba==0.61.2->vllm)
#   Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (2.27.5)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch==2.9.1->vllm)
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.1->vllm) (1.13.1.3)
# Collecting triton==3.5.1 (from torch==2.9.1->vllm)
#   Downloading triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (1.22.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm) (1.3.1)
# Requirement already satisfied: starlette>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm) (0.0.4)
# Collecting fastapi-cli>=0.0.8 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
#   Downloading fastapi_cli-0.0.24-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.0.22)
# Collecting email-validator>=2.0.0 (from fastapi[standard]>=0.115.0->vllm)
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.41.0)
# Requirement already satisfied: pydantic-settings>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (2.13.1)
# Collecting pydantic-extra-types>=2.0.0 (from fastapi[standard]>=0.115.0->vllm)
#   Downloading pydantic_extra_types-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: jsonschema>=4.21.1 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.9.0->mistral_common[image]>=1.9.0->vllm) (4.26.0)
# Collecting jmespath (from model-hosting-container-standards<1.0.0,>=0.1.13->vllm)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting supervisor>=4.2.0 (from model-hosting-container-standards<1.0.0,>=0.1.13->vllm)
#   Downloading supervisor-4.3.0-py2.py3-none-any.whl.metadata (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.12.0->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.12.0->vllm) (2.41.4)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray>=2.48.0->ray[cgraph]>=2.48.0->vllm) (1.1.2)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]>=2.48.0->vllm) (14.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (2026.1.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.21.1->vllm) (1.4.1)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers>=0.21.1->vllm)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5,>=4.56.0->vllm) (0.7.0)
# Collecting protobuf!=6.30.*,!=6.31.*,!=6.32.*,!=6.33.0.*,!=6.33.1.*,!=6.33.2.*,!=6.33.3.*,!=6.33.4.*,>=5.29.6 (from vllm)
#   Downloading protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp->vllm) (0.4.3)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp->vllm) (2.11.0)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp->vllm) (3.2.0)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typer>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.24.1)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
#   Downloading rich_toolkit-0.19.7-py3-none-any.whl.metadata (1.0 kB)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
#   Downloading fastapi_cloud_cli-0.14.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic>=0.71.0->vllm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic>=0.71.0->vllm) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.21.1->vllm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.9.1->vllm) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.9.0->mistral_common[image]>=1.9.0->vllm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.9.0->mistral_common[image]>=1.9.0->vllm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.9.0->mistral_common[image]>=1.9.0->vllm) (0.30.0)
# Collecting nvidia-cutlass-dsl-libs-base==4.4.0 (from nvidia-cutlass-dsl>=4.3.4->flashinfer-python==0.6.3->vllm)
#   Downloading nvidia_cutlass_dsl_libs_base-4.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: cuda-python>=12.8 in /usr/local/lib/python3.12/dist-packages (from nvidia-cutlass-dsl-libs-base==4.4.0->nvidia-cutlass-dsl>=4.3.4->flashinfer-python==0.6.3->vllm) (12.9.4)
# Collecting pycountry>=23 (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.9.0->mistral_common[image]>=1.9.0->vllm)
#   Downloading pycountry-26.2.16-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.0.0->fastapi[standard]>=0.115.0->vllm) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp->vllm) (43.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.9.1->vllm) (1.3.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.22.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (15.0.1)
# Requirement already satisfied: cuda-pathfinder==1.*,>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda12x->ray[cgraph]>=2.48.0->vllm) (1.3.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp->vllm) (2.0.0)
# Collecting rignore>=0.5.1 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
#   Downloading rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (2.53.0)
# Collecting fastar>=0.8.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
#   Downloading fastar-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (13.9.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.16.0->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp->vllm) (3.0)
# Requirement already satisfied: cuda-bindings~=12.9.4 in /usr/local/lib/python3.12/dist-packages (from cuda-python>=12.8->nvidia-cutlass-dsl-libs-base==4.4.0->nvidia-cutlass-dsl>=4.3.4->flashinfer-python==0.6.3->vllm) (12.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.1.2)
# Downloading vllm-0.16.0-cp38-abi3-manylinux_2_31_x86_64.whl (508.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.3/508.3 MB 2.7 MB/s eta 0:00:00
# Downloading compressed_tensors-0.13.0-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.6/192.6 kB 21.2 MB/s eta 0:00:00
# Downloading depyf-0.20.0-py3-none-any.whl (39 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.5 MB/s eta 0:00:00
# Downloading flashinfer_python-0.6.3-py3-none-any.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 104.8 MB/s eta 0:00:00
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 14.4 MB/s eta 0:00:00
# Downloading lm_format_enforcer-0.11.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 5.5 MB/s eta 0:00:00
# Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 111.6 MB/s eta 0:00:00
# Downloading outlines_core-0.2.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 93.3 MB/s eta 0:00:00
# Downloading torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (899.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 2.1 MB/s eta 0:00:00
# Downloading torchaudio-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 97.4 MB/s eta 0:00:00
# Downloading torchvision-0.24.1-cp312-cp312-manylinux_2_28_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 130.0 MB/s eta 0:00:00
# Downloading xgrammar-0.1.29-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 68.0 MB/s eta 0:00:00
# Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 19.1 MB/s eta 0:00:00
# Downloading triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 5.5 MB/s eta 0:00:00
# Downloading anthropic-0.84.0-py3-none-any.whl (455 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.2/455.2 kB 29.8 MB/s eta 0:00:00
# Downloading gguf-0.17.1-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 13.7 MB/s eta 0:00:00
# Downloading llguidance-1.3.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 85.9 MB/s eta 0:00:00
# Downloading mistral_common-1.9.1-py3-none-any.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 92.2 MB/s eta 0:00:00
# Downloading model_hosting_container_standards-0.1.13-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 14.4 MB/s eta 0:00:00
# Downloading openai_harmony-0.0.8-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 106.8 MB/s eta 0:00:00
# Downloading prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl (19 kB)
# Downloading ray-2.54.0-cp312-cp312-manylinux2014_x86_64.whl (73.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.0/73.0 MB 34.7 MB/s eta 0:00:00
# Downloading setuptools-80.10.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 45.4 MB/s eta 0:00:00
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 98.9 MB/s eta 0:00:00
# Downloading blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (388 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 40.5 MB/s eta 0:00:00
# Downloading cbor2-5.8.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.4/285.4 kB 33.1 MB/s eta 0:00:00
# Downloading grpcio_reflection-1.78.0-py3-none-any.whl (22 kB)
# Downloading protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.5/323.5 kB 36.9 MB/s eta 0:00:00
# Downloading ijson-3.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 20.0 MB/s eta 0:00:00
# Downloading msgspec-0.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 28.5 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 22.3 MB/s eta 0:00:00
# Downloading partial_json_parser-0.2.1.1.post7-py3-none-any.whl (10 kB)
# Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 9.3 MB/s eta 0:00:00
# Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (32 kB)
# Downloading apache_tvm_ffi-0.1.8.post2-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 104.9 MB/s eta 0:00:00
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading fastapi_cli-0.0.24-py3-none-any.whl (12 kB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 52.8 MB/s eta 0:00:00
# Downloading interegular-0.3.3-py37-none-any.whl (23 kB)
# Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 62.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_frontend-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 77.8 MB/s eta 0:00:00
# Downloading nvidia_cutlass_dsl-4.4.0-py3-none-any.whl (10 kB)
# Downloading nvidia_cutlass_dsl_libs_base-4.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (74.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 MB 35.2 MB/s eta 0:00:00
# Downloading pydantic_extra_types-2.11.0-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 10.2 MB/s eta 0:00:00
# Downloading supervisor-4.3.0-py2.py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 36.6 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 8.2 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 37.4 MB/s eta 0:00:00
# Downloading fastapi_cloud_cli-0.14.0-py3-none-any.whl (28 kB)
# Downloading pycountry-26.2.16-py3-none-any.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 148.1 MB/s eta 0:00:00
# Downloading rich_toolkit-0.19.7-py3-none-any.whl (32 kB)
# Downloading fastar-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (821 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.6/821.6 kB 57.4 MB/s eta 0:00:00
# Downloading rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (959 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 72.2 MB/s eta 0:00:00
# Installing collected packages: supervisor, triton, setuptools, setproctitle, rignore, pycountry, pybase64, protobuf, partial-json-parser, outlines_core, nvidia-nvshmem-cu12, nvidia-cudnn-frontend, ninja, msgspec, loguru, llvmlite, llguidance, lark, jmespath, interegular, ijson, gguf, fastar, dnspython, diskcache, cbor2, blake3, astor, apache-tvm-ffi, numba, huggingface-hub, grpcio-reflection, email-validator, depyf, torch, rich-toolkit, pydantic-extra-types, prometheus-fastapi-instrumentator, openai-harmony, nvidia-cutlass-dsl-libs-base, lm-format-enforcer, anthropic, transformers, torchvision, torchaudio, ray, nvidia-cutlass-dsl, model-hosting-container-standards, fastapi-cloud-cli, fastapi-cli, xgrammar, mistral_common, flashinfer-python, compressed-tensors, vllm
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
#   Attempting uninstall: nvidia-nvshmem-cu12
#     Found existing installation: nvidia-nvshmem-cu12 3.4.5
#     Uninstalling nvidia-nvshmem-cu12-3.4.5:
#       Successfully uninstalled nvidia-nvshmem-cu12-3.4.5
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: lark
#     Found existing installation: lark 1.3.1
#     Uninstalling lark-1.3.1:
#       Successfully uninstalled lark-1.3.1
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.10.0+cu128
#     Uninstalling torch-2.10.0+cu128:
#       Successfully uninstalled torch-2.10.0+cu128
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.25.0+cu128
#     Uninstalling torchvision-0.25.0+cu128:
#       Successfully uninstalled torchvision-0.25.0+cu128
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.10.0+cu128
#     Uninstalling torchaudio-2.10.0+cu128:
#       Successfully uninstalled torchaudio-2.10.0+cu128
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.5 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.5 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.5 which is incompatible.
# Successfully installed anthropic-0.84.0 apache-tvm-ffi-0.1.8.post2 astor-0.8.1 blake3-1.0.8 cbor2-5.8.0 compressed-tensors-0.13.0 depyf-0.20.0 diskcache-5.6.3 dnspython-2.8.0 email-validator-2.3.0 fastapi-cli-0.0.24 fastapi-cloud-cli-0.14.0 fastar-0.8.0 flashinfer-python-0.6.3 gguf-0.17.1 grpcio-reflection-1.78.0 huggingface-hub-0.36.2 ijson-3.5.0 interegular-0.3.3 jmespath-1.1.0 lark-1.2.2 llguidance-1.3.0 llvmlite-0.44.0 lm-format-enforcer-0.11.3 loguru-0.7.3 mistral_common-1.9.1 model-hosting-container-standards-0.1.13 msgspec-0.20.0 ninja-1.13.0 numba-0.61.2 nvidia-cudnn-frontend-1.18.0 nvidia-cutlass-dsl-4.4.0 nvidia-cutlass-dsl-libs-base-4.4.0 nvidia-nvshmem-cu12-3.3.20 openai-harmony-0.0.8 outlines_core-0.2.11 partial-json-parser-0.2.1.1.post7 prometheus-fastapi-instrumentator-7.1.0 protobuf-6.33.5 pybase64-1.4.3 pycountry-26.2.16 pydantic-extra-types-2.11.0 ray-2.54.0 rich-toolkit-0.19.7 rignore-0.7.6 setproctitle-1.3.7 setuptools-80.10.2 supervisor-4.3.0 torch-2.9.1 torchaudio-2.9.1 torchvision-0.24.1 transformers-4.57.6 triton-3.5.1 vllm-0.16.0 xgrammar-0.1.29
# Found existing installation: protobuf 6.33.5
# Uninstalling protobuf-6.33.5:
#   Successfully uninstalled protobuf-6.33.5
# Collecting protobuf==4.25.3
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 23.1 MB/s eta 0:00:00
# Installing collected packages: protobuf
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-reflection 1.78.0 requires protobuf<7.0.0,>=6.31.1, but you have protobuf 4.25.3 which is incompatible.
# vllm 0.16.0 requires protobuf!=6.30.*,!=6.31.*,!=6.32.*,!=6.33.0.*,!=6.33.1.*,!=6.33.2.*,!=6.33.3.*,!=6.33.4.*,>=5.29.6, but you have protobuf 4.25.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.3 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.3 which is incompatible.
# google-api-core 2.30.0 requires protobuf<7.0.0,>=4.25.8, but you have protobuf 4.25.3 which is incompatible.
# grain 0.2.15 requires protobuf>=5.28.3, but you have protobuf 4.25.3 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.3 which is incompatible.
# Successfully installed protobuf-4.25.3

# %%
# !nohup python -m vllm.entrypoints.openai.api_server \
#   --model Llama-3.1-Nemotron-Nano-4B-v1.1 \
#   --trust-remote-code \
#   --seed 1 \
#   --host 0.0.0.0 \
#   --port 5000 \
#   --served-model-name "Llama-Nemotron-Nano-4B" \
#   --tensor-parallel-size 1 \
#   --max-model-len 50_000 \
#   --gpu-memory-utilization 0.95 \
#   --enforce-eager \
#   --enable-auto-tool-choice \
#   --tool-parser-plugin "Llama-3.1-Nemotron-Nano-4B-v1.1/llama_nemotron_nano_toolcall_parser.py" \
#   --tool-call-parser "llama_nemotron_json" \
#   --chat-template "Llama-3.1-Nemotron-Nano-4B-v1.1/llama_nemotron_nano_generic_tool_calling.jinja" \
#   > vllm.log &
# Out:
# nohup: redirecting stderr to stdout

# %%
# !nohup python -m vllm.entrypoints.openai.api_server \
  --model Llama-3.1-Nemotron-Nano-4B-v1.1 \
  --trust-remote-code \
  --host 0.0.0.0 \
  --port 5000 \
  --served-model-name Llama-Nemotron-Nano-4B \
  --tensor-parallel-size 1 \
  --max-model-len 8192 \
  --gpu-memory-utilization 0.85 \
  --enable-auto-tool-choice \
  --tool-call-parser llama3_json \
  > vllm.log 2>&1 &

# %% [markdown]
# **Verify instance is spinning up**

# %%
# !while ! grep -q "Application startup complete" vllm.log; do tail -n 1 vllm.log; sleep 5; done
# Out:
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (APIServer pid=14690) INFO 02-27 05:01:59 [vllm.py:689] Asynchronous scheduling is enabled.
# W0000 00:00:1772168525.861734   14832 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772168525.861734   14832 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (EngineCore_DP0 pid=14832) INFO 02-27 05:02:16 [core.py:97] Initializing a V1 LLM engine (v0.16.0) with config: model='Llama-3.1-Nemotron-Nano-4B-v1.1', speculative_config=None, tokenizer='Llama-3.1-Nemotron-Nano-4B-v1.1', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.bfloat16, max_seq_len=8192, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=Llama-Nemotron-Nano-4B, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'level': None, 'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'splitting_ops': ['vllm::unified_attention', 'vllm::unified_attention_with_output', 'vllm::unified_mla_attention', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::plamo2_mamba_mixer', 'vllm::gdn_attention_core', 'vllm::kda_attention', 'vllm::sparse_attn_indexer', 'vllm::rocm_aiter_sparse_attn_indexer', 'vllm::unified_kv_cache_update'], 'compile_mm_encoder': False, 'compile_sizes': [], 'compile_ranges_split_points': [2048], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'eliminate_noops': True, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False, 'fuse_act_padding': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': True, 'static_all_moe_layers': []}
# Loading safetensors checkpoint shards:  50% Completed | 1/2 [00:01<00:01,  1.30s/it]
# (EngineCore_DP0 pid=14832) INFO 02-27 05:02:24 [gpu_model_runner.py:4221] Model loading took 8.44 GiB memory and 4.016891 seconds
# (EngineCore_DP0 pid=14832) INFO 02-27 05:02:24 [gpu_model_runner.py:4221] Model loading took 8.44 GiB memory and 4.016891 seconds
# (EngineCore_DP0 pid=14832) INFO 02-27 05:02:32 [backends.py:976] Dynamo bytecode transform time: 8.00 s
# (EngineCore_DP0 pid=14832) INFO 02-27 05:02:42 [monitor.py:34] torch.compile takes 9.90 s in total
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  67%|██████▋   | 34/51 [00:03<00:01, 12.08it/s](EngineCore_DP0 pid=14832) INFO 02-27 05:02:51 [core.py:278] init engine (profile, create kv cache, warmup model) took 27.37 seconds

# %% [markdown]
# **Set up OpenAI Client**

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://0.0.0.0:5000/v1",
    api_key="dummy"
)

# %% [markdown]
# **For binary output classification task, I use reasoning off mode.**

# %%
import pandas as pd

# %%
FEATURE_GROUPS = {
    "Rhythm": [
        "steps_48phi", "steps_8phi", "steps_psd_auc_64h",
        "steps_12p_reject", "steps_128p_reject", "steps_IV"
    ],
    "Heart Rate Variability": [
        "hrstd_max", "hrstd_std", "hrmax_std", "hrmean_max",
        "hrmax_mean", "hrentropy_std", "RestingHeartRate_std", "hrmax_max"
    ],
    "Shift Pattern": [
        "shift_hours_median", "shift_type_shannon_entropy",
        "shift_hours_shannon_entropy"
    ],
    "Inactivity at Daytime": [
        "duration_entropy_non_step_std"
    ],
    "Morning Energy": [
        "happiness_morning_std", "happiness_morning_shannon_entropy",
        "sleepiness_daytime_shannon_entropy", "energy_morning_std",
        "alterness_morning_std", "happiness_morning_median"
    ],
    "Evening Energy": [
        "energy_evening_median", "relax_evening_median",
        "health_evening_std", "energy_evening_std",
        "health_evening_median", "happiness_evening_median",
        "happiness_evening_std"
    ],
    "Caffeine Intake": [
        "caffeine_cups_shannon_entropy",
        "awake_type_shannon_entropy",
        "awake_type_std",
        "awake_type_median"
    ],
    "Sleep": [
        "sleep_efficiency_median",
        "sleep_duration_max",
        "nap_duration_fitbit_max"
    ]
}

# %%
data = pd.read_json("/content/all_participants_features.json")
data.head()
# Out:
#                                                                      1002  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 24.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 3.201355533001174, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.7841672614...
# Morning Energy          {'alterness_morning_std': 34.09432393964113, '...
#
#                                                                      1102  \
# Caffeine Intake         {'awake_type_median': 0.5, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 41.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 2.171339382665621, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.2422038221...
# Morning Energy          {'alterness_morning_std': 23.499438111352696, ...
#
#                                                                      1103  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 68.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 1.9563385338022201, '...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.2239061320...
# Morning Energy          {'alterness_morning_std': 23.097668295777268, ...
#
#                                                                      1105  \
# Caffeine Intake         {'awake_type_median': 1.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 80.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 1.687253803322248, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.2581546889...
# Morning Energy          {'alterness_morning_std': 17.354356974666068, ...
#
#                                                                      1108  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 28.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 2.102938060155001, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.3309113415...
# Morning Energy          {'alterness_morning_std': 34.85299368535174, '...
#
#                                                                      1115  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 70.5, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 1.6523191974188092, '...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.3537110787...
# Morning Energy          {'alterness_morning_std': 29.754982880371156, ...
#
#                                                                      1150  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 30.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 2.317587564950268, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.3038594506...
# Morning Energy          {'alterness_morning_std': 12.27180962669054, '...
#
#                                                                      1151  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 35.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 1.323591303761829, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.2673526136...
# Morning Energy          {'alterness_morning_std': 28.46492548870867, '...
#
#                                                                      1153  \
# Caffeine Intake         {'awake_type_median': 1.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 43.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 2.081526510338128, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.2681467520...
# Morning Energy          {'alterness_morning_std': 27.631696726475266, ...
#
#                                                                      1154  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 31.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 1.974309473688939, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.3458715151...
# Morning Energy          {'alterness_morning_std': 23.212925361663356, ...
#
#                         ...  \
# Caffeine Intake         ...
# Evening Energy          ...
# Heart Rate Variability  ...
# Inactivity at Daytime   ...
# Morning Energy          ...
#
#                                                                      1307  \
# Caffeine Intake         {'awake_type_median': 1.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 16.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 2.6592428585304493, '...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.3844192995...
# Morning Energy          {'alterness_morning_std': 21.606755338905465, ...
#
#                                                                      1308  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 36.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 4.311667448966372, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.5441071863...
# Morning Energy          {'alterness_morning_std': 27.797440664742528, ...
#
#                                                                      1309  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 0.0, 'energy_evening...
# Heart Rate Variability  {'RestingHeartRate_std': 3.649530529229613, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.3027201647...
# Morning Energy          {'alterness_morning_std': 30.687901547380083, ...
#
#                                                                      1310  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 30.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 3.228659539846594, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.4376681703...
# Morning Energy          {'alterness_morning_std': 21.69475582766827, '...
#
#                                                                      1311  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 10.0, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 2.304064261519655, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.3352220905...
# Morning Energy          {'alterness_morning_std': 33.76830625694286, '...
#
#                                                                      1312  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 12.5, 'energy_evenin...
# Heart Rate Variability  {'RestingHeartRate_std': 1.86677488863775, 'hr...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.2424054047...
# Morning Energy          {'alterness_morning_std': 33.707203868388575, ...
#
#                                                                      1313  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 0.0, 'energy_evening...
# Heart Rate Variability  {'RestingHeartRate_std': 2.960453633193011, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.5396320139...
# Morning Energy          {'alterness_morning_std': 20.357115980723588, ...
#
#                                                                      1314  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 0.0, 'energy_evening...
# Heart Rate Variability  {'RestingHeartRate_std': 2.97209241668783, 'hr...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.3177600143...
# Morning Energy          {'alterness_morning_std': 24.232569698868637, ...
#
#                                                                      1315  \
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 0.0, 'energy_evening...
# Heart Rate Variability  {'RestingHeartRate_std': 3.001574036011307, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.6498327248...
# Morning Energy          {'alterness_morning_std': 26.375375194803706, ...
#
#                                                                      1316
# Caffeine Intake         {'awake_type_median': 0.0, 'awake_type_shannon...
# Evening Energy          {'energy_evening_median': 0.0, 'energy_evening...
# Heart Rate Variability  {'RestingHeartRate_std': 3.299605273056646, 'h...
# Inactivity at Daytime   {'duration_entropy_non_step_std': 0.3773596102...
# Morning Energy          {'alterness_morning_std': 21.804031495888182, ...
#
# [5 rows x 44 columns]

# %%
detailed_thinking = "off"

def build_grouped_data(row):
    grouped = {}

    for group, columns in FEATURE_GROUPS.items():
        grouped[group] = {
            col: row[col]
            for col in columns
            if col in row and not pd.isna(row[col])
        }

    return grouped

# %%
def build_prompt(grouped_dict):
    formatted_sections = []

    for group, features in grouped_dict.items():
        section = f"## {group}\n"
        for k, v in features.items():
            section += f"{k}: {v}\n"
        formatted_sections.append(section)

    data_block = "\n".join(formatted_sections)

    prompt = f"""
You are a behavioral health data analyst.

Below is structured wearable and survey-derived feature data grouped by domain.

Write a concise professional summary describing:
- Circadian rhythm stability
- Cardiovascular variability
- Work/shift regularity
- Daytime inactivity
- Morning and evening energy patterns
- Sleep quality

Interpret patterns at a high level.
Do NOT list features individually.
Do NOT invent values.

Data:
{data_block}

Summary:
"""
    return prompt.strip()

# %%
def build_classification_prompt(summary):
    return f"""
You are a clinical burnout assessment assistant.

Based ONLY on the following behavioral health summary,
classify burnout risk as either:

- High
- Low

Rules:
- Output EXACTLY one word: High or Low
- Do not explain your reasoning
- Do not output anything else

Summary:
{summary}

Burnout Risk:
""".strip()

# %% [markdown]
# **Test single record**

# %%
response = client.chat.completions.create(
    model="Llama-Nemotron-Nano-4B",
    messages=[
        {"role": "user", "content": build_prompt(grouped_data)}
    ],
    # reasoning off temperature = 0.0
    temperature=0.0,
    extra_body={
        "detailed_thinking": "off"
    }
)

print(response.choices[0].message.content)
# Out:
# **Professional Summary: Behavioral Health Insights from Feature Data**
#
# This analysis provides a high-level interpretation of behavioral health patterns inferred from the provided wearable and survey data, grouped by domain:
#
# * **Circadian Rhythm Stability**: Noted deviations suggest potential impacts on overall health, with fluctuations in step counts (steps_48phi, steps_8phi, steps_12p_reject, steps_IV) indicating possible circadian rhythm disruptions.
# * **Cardiovascular Variability**: Elevated Heart Rate Variability (HRVD), particularly hrmax_std and hrentropy_std, may reflect increased cardiovascular stress levels, with peak heart rates (hrmax_mean, hrmax_max) suggesting high physical demand during work shifts.
# * **Work/Shift Regularity**: Low median shift hours and specific entropy values (shift_type_shannon_entropy, shift_hours_shannon_entropy) imply irregular work schedules, potentially contributing to health disparities.
# * **Daytime Inactivity**: Elevated non-step duration entropy (duration_entropy_non-step_std) suggests sedentary behavior during daylight hours, a critical risk factor for various conditions.
# * **Morning and Evening Energy Patterns**: Significant differences in morning and evening energy metrics (energy_std, health_std, happiness/alterness/relax metrics) indicate circadian rhythm effects, with morning energy potentially indicative of morning stiffness or fatigue, contrasting sharply with evening relaxation and health benefits.
# * **Sleep Quality**: Excellent sleep efficiency (sleep_efficiency_median: 94.0), prolonged maximum sleep duration (sleep_duration_max: 602.5 minutes), and Fitbit-derived nap duration (nap_duration_fitbit_max: 152.0 minutes) suggest optimal sleep outcomes, likely contributing to improved well-being.
#
# **Key Takeaways for Behavioral Health:**
# - **Circadian Misalignment**: Inactivity patterns and energy disparities across day/night suggest potential misalignment between internal circadian rhythms and external schedules, necessitating consideration for schedule adjustments or lifestyle interventions.
# - **Cardiovascular Stress**: Elevated HRVD and peak heart rates underscore the importance of managing physical stress levels, particularly during work shifts.
# - **Work Schedule Irregularities**: Irregular work hours and entropy values may indicate productivity challenges or health concerns associated with non-standard work schedules.
# - **Sleep Optimization**: The data highlights the significance of achieving and maintaining quality sleep, suggesting opportunities for sleep hygiene interventions.
# - **Holistic Health Implications**: The interplay between circadian rhythms, physical activity, cardiovascular health, and sleep underscores the need for integrated health promotion strategies that address these interconnected factors. **Clinical interpretation should consider individual baselines and contextual factors (e.g., work schedules, caffeine intake) to tailor preventive and therapeutic measures effectively.**
#
# **Clinical Actionability Suggestions:**
# - **Schedule Adjustments**: Explore flexible scheduling options for employees with circadian rhythm concerns.
# - **Physical Activity Promotion**: Tailor physical activity recommendations based on circadian energy patterns to optimize productivity and health.
# - **Caffeine Awareness**: Monitor caffeine intake effects, especially for individuals with circadian misalignment or cardiovascular concerns.
# - **Sleep Hygiene Interventions**: Offer sleep hygiene resources (e.g., dark therapy, pre-sleep routines) to support sleep quality.
# - **Regular Health Check-Ups**: Incorporate circadian, cardiovascular, and activity level monitoring into routine health assessments to inform preventive care.
#
# **Limitations of Summary:** This summary interprets the data at a high level without direct correlation to specific individual health outcomes. Clinical validation and individualized assessments are recommended for actionable insights. **For precise clinical applications, longitudinal analysis and integration with clinical outcomes are necessary.**
#
# **Recommendation for Future Analysis:** Incorporate additional features (e.g., stress levels, mood, metabolic markers) to deepen insights into the interplay between these health domains and provide more targeted recommendations. **Data visualization tools could enhance the clarity of complex patterns, facilitating better communication with healthcare professionals.**
#
# **Confidentiality Note:** This summary is for informational purposes only and should not be used for direct clinical decision-making without consulting healthcare professionals or protected health information (PHI). **Ensure all data is anonymized before sharing in a clinical setting.**
#
# ---
# * **Word Count: 298** *Typical for a high-level summary; detailed reports would expand on these insights.*
# * **Key Areas for Further Investigation:** Integration with clinical outcomes, longitudinal analysis, and incorporating additional health-related features for more nuanced insights.
# * **Methodological Assumptions:** Data anonymization, confidentiality safeguards, and interpretation grounded in established behavioral health principles. **Contextual factors (e.g., work environment, individual baselines) should be considered for accurate clinical application.**
# * **Clinical Decision-Making Framework:** Summary insights should inform, not dictate, clinical decisions; always prioritize individualized care and contextual understanding. **Multidisciplinary collaboration (healthcare professionals, data analysts) is essential for translating data into actionable strategies.**
#
# ---
# * **Enhanced Summary Option:** For a condensed version tailored to specific stakeholders (e.g., HR, Healthcare Providers), I can provide a tailored summary focusing on key recommendations and implications for their use cases. Please specify your requirements.
# * **Detailed Analysis:** For a comprehensive report, I can provide a deeper examination of patterns, statistical methods used, and recommendations for each domain, including methodologies and confidence intervals where applicable. Please indicate your need.
# * **Data Limitations Acknowledgement:** While efforts are made to provide a thorough summary, acknowledge that:
#     - **Sample Size and Representativeness**: The sample size and representativeness of the data are not specified; thus, findings are interpreted within this caveat.
#     - **Feature Selection and Model Assumptions**: The interpretation assumes the features listed are relevant and the model assumptions (not detailed here) are met.
#     - **Clinical Correlation**: Findings are theoretical interpretations; direct correlation with clinical outcomes requires further research.
#     - **Ethical and Privacy Considerations**: Emphasizes the need for data anonymization and confidentiality protocols in handling such sensitive health information in real-world applications. **Always prioritize ethical data handling practices in deployment.**
#
# ---
# **Next Steps:** Depending on your request, I'm prepared to:
# 1. **Condensed Summary**: Tailor to a specific stakeholder's needs.
# 2. **Comprehensive Analysis**: Provide detailed statistical analysis and recommendations.
# 3. **Discussion and Interpretation Guidance**: Offer guidance on how to discuss findings with stakeholders or interpret results in a clinical context.
# **Please respond with your preferred direction for the summary's depth and application.**

# %%
summary_text = response.choices[0].message.content

# %%
classification_response = client.chat.completions.create(
    model="Llama-Nemotron-Nano-4B",
    messages=[
        {"role": "user", "content": build_classification_prompt(summary_text)}
    ],
    temperature=0.0,  # deterministic classification
    extra_body={
        "detailed_thinking": "off"
    }
)

burnout_label = classification_response.choices[0].message.content.strip()

print("Burnout Classification:", burnout_label)
# Out:
# Burnout Classification: High

# %% [markdown]
# **Whole Dataset**

# %%
from openai import APIConnectionError
import time

results = []

print(f"Processing {len(data.columns)} participants...")

for participant_id, grouped_data in data.items():
    try:
        # Generate summary
        summary_response = client.chat.completions.create(
            model="Llama-Nemotron-Nano-4B",
            messages=[
                {"role": "user", "content": build_prompt(grouped_data)}
            ],
            temperature=0.3,
            extra_body={"detailed_thinking": "off"}
        )

        summary_text = summary_response.choices[0].message.content.strip()

        # Classification
        classification_response = client.chat.completions.create(
            model="Llama-Nemotron-Nano-4B",
            messages=[
                {"role": "user", "content": build_classification_prompt(summary_text)}
            ],
            temperature=0.0,
            max_tokens=3,
            extra_body={"detailed_thinking": "off"}
        )

        burnout_label = classification_response.choices[0].message.content.strip()

        results.append({
            "ID": participant_id,
            "llm_summary": summary_text,
            "llm_burnout_label": burnout_label
        })

        # Optional: verify progress
        print(f"Processed {participant_id}: {burnout_label}")

    except APIConnectionError:
        print("CRITICAL ERROR: Could not connect to vLLM server. It may have crashed.")
        print("Please check the 'vllm.log' or restart the server cell.")
        break
    except Exception as e:
        print(f"Error processing {participant_id}: {e}")
        continue

df_results = pd.DataFrame(results)

if not df_results.empty:
    print(df_results[["ID", "llm_burnout_label"]].head())
else:
    print("No results generated due to connection error.")
# Out:
# Processing 44 participants...
# Processed 1002: High
# Processed 1102: High
# Processed 1103: High
# Processed 1105: High
# Processed 1108: High
# Processed 1115: High
# Processed 1150: Low
# Processed 1151: High
# Processed 1153: High
# Processed 1154: Low
# Processed 1155: High
# Processed 1156: Low
# Processed 1157: High
# Processed 1158: High
# Processed 1164: High
# Processed 1178: High
# Processed 1179: High
# Processed 1180: High
# Processed 1181: High
# Processed 1182: High
# Processed 1183: High
# Processed 1184: High
# Processed 1185: High
# Processed 1186: High
# Processed 1187: High
# Processed 1188: High
# Processed 1189: High
# Processed 1190: High
# Processed 1191: High
# Processed 1192: High
# Processed 1193: High
# Processed 1194: High
# Processed 1195: Low
# Processed 1305: High
# Processed 1307: High
# Processed 1308: High
# Processed 1309: Low
# Processed 1310: High
# Processed 1311: High
# Processed 1312: High
# Processed 1313: High
# Processed 1314: High
# Processed 1315: High
# Processed 1316: High
#      ID llm_burnout_label
# 0  1002              High
# 1  1102              High
# 2  1103              High
# 3  1105              High
# 4  1108              High

# %%
df_results.to_csv("llm_predictions.csv", index=False)

# %%
ground_truth = pd.read_csv("/content/jbs_scores_post.csv")
df_results["ID"] = df_results["ID"].astype(str)
ground_truth.rename(columns={"u_id": "ID"}, inplace=True)
ground_truth["ID"] = ground_truth["ID"].astype(str)

# Merge
df_eval = df_results.merge(
    ground_truth,
    on="ID",
    how="inner"
)

print("Merged shape:", df_eval.shape)
# Out:
# Merged shape: (44, 10)

# %%
df_eval["llm_burnout_label"] = (
    df_eval["llm_burnout_label"]
    .astype(str)
    .str.strip()
    .str.capitalize()
)

df_eval["risk"] = df_eval["risk"].map({1: "High", 0: "Low"})

# %%
from sklearn.metrics import accuracy_score, classification_report

accuracy = accuracy_score(
    df_eval["risk"],
    df_eval["llm_burnout_label"]
)

print("Accuracy:", accuracy)

print("\nDetailed Report:")
print(classification_report(
    df_eval["risk"],
    df_eval["llm_burnout_label"]
))
# Out:
# Accuracy: 0.8409090909090909
#
# Detailed Report:
#               precision    recall  f1-score   support
#
#         High       0.90      0.92      0.91        38
#          Low       0.40      0.33      0.36         6
#
#     accuracy                           0.84        44
#    macro avg       0.65      0.63      0.64        44
# weighted avg       0.83      0.84      0.83        44
